# %%
from qiskit import QuantumCircuit, transpile, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit_mps_initializer.datatypes import QuantumState
from qiskit.quantum_info import partial_trace, DensityMatrix, state_fidelity
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# --- define psi and phi ---
psi = [1, 2, 3, 4, 5, 6, 7, 8]        

# Exponential phi
N = 8
alpha = 0.5  # controls steepness
phi = np.exp(alpha * np.arange(N))     # phi = [1, e^α, e^{2α}, ..., e^{(N-1)α}]

n = 3                    # number of qubits (log2 of vector length)
number_of_layers = 2     # layers for MPS initialization

# --- create normalized QuantumState objects ---
psi_state = QuantumState.from_dense_data(data=psi, normalize=True)
phi_state = QuantumState.from_dense_data(data=phi, normalize=True)

# --- generate MPS initializer circuits ---
U_psi = psi_state.generate_mps_initializer_circuit(number_of_layers=number_of_layers)
U_phi = phi_state.generate_mps_initializer_circuit(number_of_layers=number_of_layers)
U_phi_dagger = U_phi.inverse()


# --- protocol function ---
def run_protocol(m, delta, return_state=False):
    psi_reg = QuantumRegister(n, name="ψ")
    phi_reg = QuantumRegister(n, name="φ")
    creg = ClassicalRegister(n, name="c")
    qc = QuantumCircuit(psi_reg, phi_reg, creg)

    # initialize states
    qc.append(U_psi, psi_reg)
    qc.append(U_phi, phi_reg)

    # iterative protocol
    for k in range(1, m+1):
        # CNOT flags
        for i in range(n):
            qc.cx(phi_reg[n-1-i], psi_reg[n-1-i], ctrl_state=0)

        # apply small phase
        qc.mcp(delta, psi_reg[0:-1], psi_reg[-1])

        # uncompute flags
        for i in range(n):
            qc.cx(phi_reg[i], psi_reg[i], ctrl_state=0)

        # uncompute φ, measure, reset
        qc.append(U_phi_dagger, phi_reg)
        qc.measure(phi_reg, creg)
        qc.reset(phi_reg)

        if k < m:
            qc.append(U_phi, phi_reg)

    # simulate
    sim = AerSimulator()
    qc.save_statevector()
    result = sim.run(transpile(qc, sim)).result()
    full_state = result.get_statevector(qc)

    # reduced density matrix for ψ
    rho_psi = partial_trace(full_state, list(range(n, 2*n)))

    # Ideal target vector with programmable phase
    psi_vec = np.array(psi) / np.linalg.norm(psi)
    phi_vec = np.array(phi) / np.linalg.norm(phi)
    phase_profile = np.exp(1j * delta * m * np.abs(phi_vec)**2)
    ideal_vec = psi_vec * phase_profile
    rho_ideal = DensityMatrix(ideal_vec)

    # fidelity
    fid = state_fidelity(rho_psi, rho_ideal)

    if return_state:
        return fid, rho_psi, ideal_vec
    return fid

# --- run for multiple iterations ---
m_values = list(range(1, 21))

# fidelity for different deltas
delta_values = [np.pi/4, np.pi/40, np.pi/400, np.pi/4000]
fidelities_list = []

for delta_val in delta_values:
    fidelities = [run_protocol(m, delta_val) for m in m_values]
    fidelities_list.append(fidelities)

# --- plot fidelity results ---
plt.figure(figsize=(20,5))
labels = [r'$\delta = \pi/4$', r'$\delta = \pi/40$', r'$\delta = \pi/400$', r'$\delta = \pi/4000$']
markers = ['o-', 's-', '^-', 'x-']
for fids, lbl, mk in zip(fidelities_list, labels, markers):
    plt.plot(m_values, fids, mk, label=lbl)
plt.xlabel("Number of iterations (m)")
plt.ylabel("Fidelity")
plt.title("Fidelity vs Iterations for Different δ (phi=[1..8])")
plt.legend()
plt.grid(True)
plt.show()

# %%
m_example = 20
delta_example = np.pi/40

fid_ex, rho_psi, ideal_vec = run_protocol(m_example, delta_example, return_state=True)
vec_sim = np.array(rho_psi.to_statevector())

# --- Align global phase ---
global_phase = np.angle(np.vdot(ideal_vec, vec_sim))
vec_sim_aligned = vec_sim * np.exp(-1j * global_phase)

# --- amplitudes and phases ---
amps_ideal = np.abs(ideal_vec)
amps_sim = np.abs(vec_sim_aligned)
phases_ideal = np.unwrap(np.angle(ideal_vec))
phases_sim = np.unwrap(np.angle(vec_sim_aligned))

print(f"Example m={m_example}, δ={delta_example:.5f}: Fidelity={fid_ex:.6f}")

# --- Phase comparison ---
plt.figure(figsize=(10,5))
plt.plot(range(N), phases_ideal, 'o-', label="Ideal Phase")
plt.plot(range(N), phases_sim, 's--', label="Simulated Phase (aligned)")
plt.axhline(0, color='black', linewidth=0.8)
plt.ylabel("Phase (radians)")
plt.xlabel("ψ basis index")
plt.title(f"Phase comparison (m={m_example}, δ={delta_example:.5f})")
plt.legend()
plt.grid(True)
plt.show()

# --- Amplitude comparison ---
plt.figure(figsize=(10,5))
plt.plot(range(N), amps_ideal, 'o-', label="Ideal Amplitude")
plt.plot(range(N), amps_sim, 's--', label="Simulated Amplitude (aligned)")
plt.ylabel("Amplitude magnitude")
plt.xlabel("ψ basis index")
plt.title(f"Amplitude comparison (m={m_example}, δ={delta_example:.5f})")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Example m=20, δ=0.07854: Fidelity=0.999971

# %%
import pandas as pd

#
phi_type = "exponential"   

# --- Save amplitude & phase data for this run ---
data = {
    "phi_type": phi_type,
    "alpha": 0.5,                 
    "delta": delta_example,
    "m": m_example,
    "phi_values": [phi],
    "amps_ideal": [amps_ideal.tolist()],
    "amps_sim": [amps_sim.tolist()],
    "phases_ideal": [phases_ideal.tolist()],
    "phases_sim": [phases_sim.tolist()],
    "fidelity": [fid_ex]
}

df = pd.DataFrame(data)
df.to_csv(f"dataset_{phi_type}.csv", index=False)
print(f"✅ Saved {phi_type} dataset → dataset_{phi_type}.csv")
# Out:
# ✅ Saved exponential dataset → dataset_exponential.csv

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator
from qiskit_mps_initializer.datatypes import QuantumState
from qiskit.quantum_info import partial_trace, DensityMatrix, state_fidelity
import numpy as np
import matplotlib.pyplot as plt

# --- define psi and uniform phi ---
psi = [1,2,3,4,5,6,7,8]
phi = [1,1,1,1,1,1,1,1]   # uniform ancilla

n = 3
number_of_layers = 2

psi_state = QuantumState.from_dense_data(data=psi, normalize=True)
phi_state = QuantumState.from_dense_data(data=phi, normalize=True)
U_psi = psi_state.generate_mps_initializer_circuit(number_of_layers=number_of_layers)
U_phi = phi_state.generate_mps_initializer_circuit(number_of_layers=number_of_layers)
U_phi_dagger = U_phi.inverse()

def build_protocol(delta, m):
    psi_reg, phi_reg = QuantumRegister(n,"ψ"), QuantumRegister(n,"φ")
    creg = ClassicalRegister(n,"c")
    qc = QuantumCircuit(psi_reg, phi_reg, creg)
    qc.append(U_psi, psi_reg)
    qc.append(U_phi, phi_reg)
    for _ in range(m):
        for i in range(n):
            qc.cx(phi_reg[n-1-i], psi_reg[n-1-i], ctrl_state=0)
        qc.mcp(delta, psi_reg[:-1], psi_reg[-1])
        for i in range(n):
            qc.cx(phi_reg[i], psi_reg[i], ctrl_state=0)
        qc.append(U_phi_dagger, phi_reg)
        qc.measure(phi_reg, creg)
        qc.reset(phi_reg)
        qc.append(U_phi, phi_reg)
    return qc

def run_fidelity(delta, m):
    qc = build_protocol(delta,m)
    sim = AerSimulator(method="statevector")
    qc.save_statevector()
    res = sim.run(transpile(qc,sim)).result()
    state = res.get_statevector(qc)
    rho_psi = partial_trace(state, list(range(n,2*n)))
    psi_vec = np.array(psi)/np.linalg.norm(psi)
    phi_vec = np.array(phi)/np.linalg.norm(phi)
    phase_profile = np.exp(1j*delta*m*np.abs(phi_vec)**2)
    ideal_vec = psi_vec*phase_profile
    rho_ideal = DensityMatrix(ideal_vec)
    return state_fidelity(rho_psi, rho_ideal), qc

def run_shots(delta,m,shots=1024):
    qc = build_protocol(delta,m)
    sim = AerSimulator()
    tqc = transpile(qc,sim)
    res = sim.run(tqc,shots=shots).result()
    counts = res.get_counts(qc)
    return counts,qc

# %%
def success_rate(delta, m=1, shots=10):
    qc = build_protocol(delta, m)
    sim = AerSimulator()
    tqc = transpile(qc, sim)

    # run with memory output for individual shots
    result = sim.run(tqc, shots=shots, memory=True).result()
    memories = result.get_memory(qc)     # list of measured bitstrings

    # count how many are all zeros
    zero_state = "0" * n
    successes = sum(1 for s in memories if s == zero_state)
    success_fraction = successes / shots

    print(f"δ = {delta:.5f}, m = {m}, shots = {shots}")
    print(f"Successful shots (ancilla = {zero_state}): {successes}/{shots}")
    print(f"Success rate = {success_fraction:.3f}")

    return success_fraction, memories, qc


# Example usage
delta = np.pi / 400
success_fraction, all_shots, qc = success_rate(delta, m=1, shots=10)
qc.draw("mpl")
# Out:
# δ = 0.00785, m = 1, shots = 10
# Successful shots (ancilla = 000): 10/10
# Success rate = 1.000

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- sweep over multiple δ values, same plot ---
def compare_deltas(delta_values, m_values, shots=200):
    """
    For each delta in delta_values, run success_rate(delta, m, shots)
    for all m in m_values and plot all curves together.
    """
    plt.figure(figsize=(20,4))
    for delta in delta_values:
        rates = [success_rate(delta, m, shots=shots)[0] for m in m_values]
        plt.plot(m_values, rates, 'o-', label=f"δ = {delta:.3e}")
    plt.xlabel("Iterations (m)")
    plt.ylabel("Success probability (ancilla = 0...0)")
    plt.title(f"Success probability vs m (shots = {shots})")
    plt.grid(True)
    plt.legend()
    plt.show()

# === Example usage ===
delta_values = [np.pi/4, np.pi/40, np.pi/100]   # list of δ values
m_values = list(range(1, 111))                   # m = 1 → 10

compare_deltas(delta_values, m_values, shots=200)
# Out:
# δ = 0.78540, m = 1, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 2, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 3, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 4, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 5, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 6, shots = 200
# Successful shots (ancilla = 000): 192/200
# Success rate = 0.960
# δ = 0.78540, m = 7, shots = 200
# Successful shots (ancilla = 000): 191/200
# Success rate = 0.955
# δ = 0.78540, m = 8, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 9, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 10, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 11, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 12, shots = 200
# Successful shots (ancilla = 000): 185/200
# Success rate = 0.925
# δ = 0.78540, m = 13, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 14, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 15, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 16, shots = 200
# Successful shots (ancilla = 000): 193/200
# Success rate = 0.965
# δ = 0.78540, m = 17, shots = 200
# Successful shots (ancilla = 000): 182/200
# Success rate = 0.910
# δ = 0.78540, m = 18, shots = 200
# Successful shots (ancilla = 000): 193/200
# Success rate = 0.965
# δ = 0.78540, m = 19, shots = 200
# Successful shots (ancilla = 000): 183/200
# Success rate = 0.915
# δ = 0.78540, m = 20, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 21, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 22, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 23, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 24, shots = 200
# Successful shots (ancilla = 000): 180/200
# Success rate = 0.900
# δ = 0.78540, m = 25, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 26, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 27, shots = 200
# Successful shots (ancilla = 000): 191/200
# Success rate = 0.955
# δ = 0.78540, m = 28, shots = 200
# Successful shots (ancilla = 000): 179/200
# Success rate = 0.895
# δ = 0.78540, m = 29, shots = 200
# Successful shots (ancilla = 000): 180/200
# Success rate = 0.900
# δ = 0.78540, m = 30, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 31, shots = 200
# Successful shots (ancilla = 000): 185/200
# Success rate = 0.925
# δ = 0.78540, m = 32, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 33, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 34, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 35, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 36, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 37, shots = 200
# Successful shots (ancilla = 000): 183/200
# Success rate = 0.915
# δ = 0.78540, m = 38, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 39, shots = 200
# Successful shots (ancilla = 000): 183/200
# Success rate = 0.915
# δ = 0.78540, m = 40, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 41, shots = 200
# Successful shots (ancilla = 000): 182/200
# Success rate = 0.910
# δ = 0.78540, m = 42, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 43, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 44, shots = 200
# Successful shots (ancilla = 000): 181/200
# Success rate = 0.905
# δ = 0.78540, m = 45, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 46, shots = 200
# Successful shots (ancilla = 000): 192/200
# Success rate = 0.960
# δ = 0.78540, m = 47, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 48, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 49, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 50, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 51, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 52, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 53, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 54, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 55, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 56, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 57, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 58, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 59, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 60, shots = 200
# Successful shots (ancilla = 000): 192/200
# Success rate = 0.960
# δ = 0.78540, m = 61, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 62, shots = 200
# Successful shots (ancilla = 000): 181/200
# Success rate = 0.905
# δ = 0.78540, m = 63, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 64, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 65, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 66, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 67, shots = 200
# Successful shots (ancilla = 000): 192/200
# Success rate = 0.960
# δ = 0.78540, m = 68, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 69, shots = 200
# Successful shots (ancilla = 000): 183/200
# Success rate = 0.915
# δ = 0.78540, m = 70, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 71, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 72, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 73, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 74, shots = 200
# Successful shots (ancilla = 000): 182/200
# Success rate = 0.910
# δ = 0.78540, m = 75, shots = 200
# Successful shots (ancilla = 000): 180/200
# Success rate = 0.900
# δ = 0.78540, m = 76, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 77, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 78, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 79, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 80, shots = 200
# Successful shots (ancilla = 000): 182/200
# Success rate = 0.910
# δ = 0.78540, m = 81, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 82, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 83, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 84, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 85, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 86, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 87, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 88, shots = 200
# Successful shots (ancilla = 000): 194/200
# Success rate = 0.970
# δ = 0.78540, m = 89, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 90, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 91, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 92, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 93, shots = 200
# Successful shots (ancilla = 000): 194/200
# Success rate = 0.970
# δ = 0.78540, m = 94, shots = 200
# Successful shots (ancilla = 000): 184/200
# Success rate = 0.920
# δ = 0.78540, m = 95, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 96, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 97, shots = 200
# Successful shots (ancilla = 000): 187/200
# Success rate = 0.935
# δ = 0.78540, m = 98, shots = 200
# Successful shots (ancilla = 000): 189/200
# Success rate = 0.945
# δ = 0.78540, m = 99, shots = 200
# Successful shots (ancilla = 000): 191/200
# Success rate = 0.955
# δ = 0.78540, m = 100, shots = 200
# Successful shots (ancilla = 000): 191/200
# Success rate = 0.955
# δ = 0.78540, m = 101, shots = 200
# Successful shots (ancilla = 000): 185/200
# Success rate = 0.925
# δ = 0.78540, m = 102, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 103, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 104, shots = 200
# Successful shots (ancilla = 000): 190/200
# Success rate = 0.950
# δ = 0.78540, m = 105, shots = 200
# Successful shots (ancilla = 000): 181/200
# Success rate = 0.905
# δ = 0.78540, m = 106, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 107, shots = 200
# Successful shots (ancilla = 000): 183/200
# Success rate = 0.915
# δ = 0.78540, m = 108, shots = 200
# Successful shots (ancilla = 000): 186/200
# Success rate = 0.930
# δ = 0.78540, m = 109, shots = 200
# Successful shots (ancilla = 000): 188/200
# Success rate = 0.940
# δ = 0.78540, m = 110, shots = 200
# Successful shots (ancilla = 000): 180/200
# Success rate = 0.900
# δ = 0.07854, m = 1, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 2, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 3, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 4, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 5, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 6, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 7, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 8, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 9, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 10, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 11, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 12, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 13, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 14, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 15, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 16, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 17, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 18, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 19, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 20, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 21, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 22, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 23, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 24, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 25, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 26, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 27, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 28, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 29, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 30, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 31, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 32, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 33, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 34, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 35, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 36, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 37, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 38, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 39, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 40, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 41, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 42, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 43, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 44, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 45, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 46, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 47, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 48, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 49, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 50, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 51, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 52, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 53, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 54, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 55, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 56, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 57, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 58, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 59, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 60, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 61, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 62, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 63, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 64, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 65, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 66, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 67, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 68, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 69, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 70, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 71, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 72, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 73, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 74, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 75, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 76, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 77, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 78, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 79, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 80, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 81, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 82, shots = 200
# Successful shots (ancilla = 000): 198/200
# Success rate = 0.990
# δ = 0.07854, m = 83, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 84, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 85, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 86, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 87, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 88, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 89, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 90, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 91, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 92, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 93, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 94, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 95, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 96, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 97, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 98, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 99, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 100, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.07854, m = 101, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 102, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 103, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 104, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 105, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 106, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 107, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 108, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 109, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.07854, m = 110, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 1, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 2, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 3, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 4, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 5, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 6, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 7, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 8, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 9, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 10, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 11, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 12, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 13, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 14, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 15, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 16, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 17, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 18, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 19, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 20, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 21, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 22, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 23, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 24, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 25, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 26, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 27, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 28, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 29, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 30, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 31, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 32, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 33, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 34, shots = 200
# Successful shots (ancilla = 000): 199/200
# Success rate = 0.995
# δ = 0.03142, m = 35, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 36, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 37, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 38, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 39, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 40, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 41, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 42, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 43, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 44, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 45, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 46, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 47, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 48, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 49, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 50, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 51, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 52, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 53, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 54, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 55, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 56, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 57, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 58, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 59, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 60, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 61, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 62, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 63, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 64, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 65, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 66, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 67, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 68, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 69, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 70, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 71, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 72, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 73, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 74, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 75, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 76, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 77, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 78, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 79, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 80, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 81, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 82, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 83, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 84, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 85, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 86, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 87, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 88, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 89, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 90, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 91, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 92, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 93, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 94, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 95, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 96, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 97, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 98, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 99, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 100, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 101, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 102, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 103, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 104, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 105, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 106, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 107, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 108, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 109, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
# δ = 0.03142, m = 110, shots = 200
# Successful shots (ancilla = 000): 200/200
# Success rate = 1.000
